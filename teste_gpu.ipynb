# %%
import torch
import torch.nn as nn
import pennylane as qml

# %%
#assert torch.cuda.is_available()
dev_torch = torch.device("cuda")

n_qubits = 4
n_layers = 2

qdev = qml.device("lightning.gpu", wires=n_qubits)

def circuit(inputs, weights):
    for i in range(n_qubits):
        qml.RX(inputs[i], wires=i)

    qml.StronglyEntanglingLayers(weights, wires=range(n_qubits))

    # >>> RETORNE UM ÚNICO TENSOR (4,) <<<
    obs = [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
    return qml.math.stack(obs)  # <- chave

qnode = qml.QNode(
    circuit,
    qdev,
    interface="torch",
    diff_method="adjoint",
)

weight_shapes = {"weights": (n_layers, n_qubits, 3)}
quantum_layer = qml.qnn.TorchLayer(qnode, weight_shapes)

class HybridNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.q = quantum_layer
        self.fc = nn.Sequential(
            nn.Linear(n_qubits, 16),
            nn.Tanh(),
            nn.Linear(16, 1),
        )

    def forward(self, x):
        q_feat = self.q(x)         # (batch, 4)
        return self.fc(q_feat)     # (batch, 1)

model = HybridNet().to(dev_torch)

# Dados
torch.manual_seed(0)
N = 512
X = (2 * torch.rand(N, n_qubits, device=dev_torch) - 1.0) * torch.pi
y = ((torch.sin(X[:, 0]) + torch.cos(X[:, 1])) > 0).float().unsqueeze(1)

opt = torch.optim.Adam(model.parameters(), lr=1e-2)
loss_fn = nn.BCEWithLogitsLoss()

for epoch in range(1, 51):
    opt.zero_grad(set_to_none=True)
    logits = model(X)
    loss = loss_fn(logits, y)
    loss.backward()
    opt.step()

    if epoch % 10 == 0:
        with torch.no_grad():
            acc = ((torch.sigmoid(logits) > 0.5) == y).float().mean().item()
        print(f"epoch={epoch:3d} loss={loss.item():.4f} acc={acc:.3f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 56
#      54 for epoch in range(1, 51):
#      55     opt.zero_grad(set_to_none=True)
# ---> 56     logits = model(X)
#      57     loss = loss_fn(logits, y)
#      58     loss.backward()
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# Cell In[4], line 40, in HybridNet.forward(self, x)
#      39 def forward(self, x):
# ---> 40     q_feat = self.q(x)         # (batch, 4)
#      41     return self.fc(q_feat)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/pennylane/qnn/torch.py:408, in TorchLayer.forward(self, inputs)
#     405     inputs = torch.reshape(inputs, (-1, inputs.shape[-1]))
#     407 # calculate the forward pass as usual
# --> 408 results = self._evaluate_qnode(inputs)
#     410 if isinstance(results, tuple):
#     411     if has_batch_dim:
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/pennylane/qnn/torch.py:434, in TorchLayer._evaluate_qnode(self, x)
#     422 """Evaluates the QNode for a single input datapoint.
#     423
#     424 Args:
#    (...)    428     tensor: output datapoint
#     429 """
#     430 kwargs = {
#     431     **{self.input_arg: x},
#     432     **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     433 }
# --> 434 res = self.qnode(**kwargs)
#     436 if isinstance(res, torch.Tensor):
#     437     return res.type(x.dtype)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/pennylane/workflow/qnode.py:895, in QNode.__call__(self, *args, **kwargs)
#     892     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     894     return capture_qnode(self, *args, **kwargs)
# --> 895 return self._impl_call(*args, **kwargs)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/pennylane/workflow/qnode.py:888, in QNode._impl_call(self, *args, **kwargs)
#     881 if (
#     882     len(tape.get_parameters(trainable_only=False)) == 0
#     883     and not self._transform_program.is_informative
#     884     and self.interface != "auto"
#     885 ):
#     886     res = _convert_to_interface(res, math.Interface(self.interface))
# --> 888 return _to_qfunc_output_type(res, self._qfunc_output, tape.shots.has_partitioned_shots)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/pennylane/workflow/qnode.py:115, in _to_qfunc_output_type(results, qfunc_output, has_partitioned_shots)
#     113     if isinstance(qfunc_output, (Sequence, qml.measurements.MeasurementProcess)):
#     114         return results
# --> 115     return type(qfunc_output)(results)
#     117 # result spec squeezes out dim for single measurement value
#     118 # we need to add it back in
#     119 if len(qfunc_output_leaves) == 1:
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/pennylane/numpy/tensor.py:112, in tensor.__new__(cls, input_array, requires_grad, *args, **kwargs)
#     111 def __new__(cls, input_array, *args, requires_grad=True, **kwargs):
# --> 112     obj = asarray(input_array, *args, **kwargs)
#     114     if isinstance(obj, onp.ndarray):
#     115         obj = obj.view(cls)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/autograd/tracer.py:54, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      52     return new_box(ans, trace, node)
#      53 else:
# ---> 54     return f_raw(*args, **kwargs)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/pennylane/numpy/tensor.py:36, in asarray(vals, *args, **kwargs)
#      34 if isinstance(vals, (onp.ndarray, _np.ndarray)):
#      35     return _np.asarray(vals, *args, **kwargs)
# ---> 36 return _np.array(vals, *args, **kwargs)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/autograd/numpy/numpy_wrapper.py:73, in array(A, *args, **kwargs)
#      71 t = builtins.type(A)
#      72 if t in (list, tuple):
# ---> 73     return array_from_args(args, kwargs, *map(array, A))
#      74 else:
#      75     return _array_from_scalar_or_array(args, kwargs, A)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/autograd/numpy/numpy_wrapper.py:75, in array(A, *args, **kwargs)
#      73     return array_from_args(args, kwargs, *map(array, A))
#      74 else:
# ---> 75     return _array_from_scalar_or_array(args, kwargs, A)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/autograd/tracer.py:54, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      52     return new_box(ans, trace, node)
#      53 else:
# ---> 54     return f_raw(*args, **kwargs)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/autograd/numpy/numpy_wrapper.py:89, in _array_from_scalar_or_array(array_args, array_kwargs, scalar)
#      87 @primitive
#      88 def _array_from_scalar_or_array(array_args, array_kwargs, scalar):
# ---> 89     return _np.array(scalar, *array_args, **array_kwargs)
#
# File ~/PhD/pinn/.venv/lib/python3.12/site-packages/torch/_tensor.py:1226, in Tensor.__array__(self, dtype)
#    1224     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1225 if dtype is None:
# -> 1226     return self.numpy()
#    1227 else:
#    1228     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
